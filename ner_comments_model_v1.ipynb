# %% [markdown]
# <a href="https://colab.research.google.com/github/brijw/DataAnalytics/blob/main/ner_comments_model_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#os is used to change the directory
import os
#spacy is used for the NER
import spacy
#pandas is used to read, edit, and write tabular data
import pandas as pd


from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MSC/Analytics/Corpus_Files/Comments.csv')
#docs = data['Comment']

# %%
from spacy import displacy
from collections import Counter
import en_core_web_sm
# spacy.cli.download("en_core_web_lg")
nlp = en_core_web_sm.load()

# import en_core_web_lg
# nlp_lg = en_core_web_lg.load()

# %%
sourcefiledirectory = '/content/drive/MyDrive/Colab Notebooks/MSC/Analytics/Corpus_Files/'
#changes the working directory to the directory specified above
os.chdir(sourcefiledirectory)
infilename = 'Comments.csv'

# %%
#creates pandas dataframe with your specified input file, using the first row as a header
df = pd.read_csv(infilename, header=0)
#creates a new column, ner_text, with entities extracted from a column titled 'Comments'
df['ner_comments'] = df['Comment'].astype(str).apply(lambda x: list({(ent.text.strip(), ent.label_) for ent in nlp(x).ents}))
#prints the values from ner_text
print(df['ner_comments'])
# Out:
# 0                                                      []
# 1                                                      []
# 2                                [(API, ORG), (MTN, ORG)]
# 3       [(Internship, ORG), (Infrastructure of Soroti ...
# 4                                    [(the 4 week, DATE)]
#                               ...
# 3869                                                   []
# 3870                                                   []
# 3871                                                   []
# 3872                                                   []
# 3873                                                   []
# Name: ner_comments, Length: 3874, dtype: object

# %%
df.head(20)
# Out:
#     comment_id                                            Comment  \
# 0            5                             djfjkdfjkjkffdk edited
# 1           41  Faith has exhibited enthusiasm in taking on th...
# 2           49  He now has now understood the structure of gra...
# 3           50  The Intern was oriented on ICT setup and Infra...
# 4           52  The student was oriented on the organization s...
# 5           53                          Activities well completed
# 6           54                                   finished on time
# 7           55  The student's weekly progress was justifiably ...
# 8           56                                              Noted
# 9           57  She found this very interesting as she was abl...
# 10          58  Partially done, expected a better result based...
# 11          63  Done to partial satisfaction. Hopefully learni...
# 12          65                       Confirmed done as specified.
# ...

# %%
df.tail(20)
# Out:
#       comment_id                                            Comment  \
# 3854        7781  Miss Nakityo was able to work on the Score fea...
# 3855        7788  Performing user acceptance tests helped the in...
# 3856        7795  Student faced the challenge of a lost laptop, ...
# 3857        7796  He is always looking for tasks. Very enthusias...
# 3858        7797  His system’s development supervisor says he is...
# 3859        7816                                                  .
# 3860        7820  Completed:\n               Configuring the net...
# 3861        7821  Completed:\n               Configuring the net...
# 3862        7822                                  Engaging teammate
# 3863        7823                                  Engaging teammate
# 3864        7824                                  Engaging teammate
# 3865        7867  Successfully installed Microsoft word to the c...
# 3866        7868  Hope you have learned something from your expe...
# ...

# %%
outfilename = 'ner_sm_'+infilename
# df.to_csv(outfilename)
